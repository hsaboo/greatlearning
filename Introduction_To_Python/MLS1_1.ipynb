# %% [markdown]
# <a href="https://colab.research.google.com/github/hsaboo/greatlearning/blob/main/MLS1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hemant")
# Out:
# Hemant
