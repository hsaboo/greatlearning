# %% [markdown]
# <a href="https://colab.research.google.com/github/hsaboo/greatlearning/blob/hsaboo-intopython/Introduction_To_Python/MLS1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hemant")
print("Swati")
# Out:
# Hemant
